# %% [markdown]
# **_The notebook is structured in the following way:_**
# - Read Malware Datasets.
# - Split data to train, test, validation.
# - Create Sequential model and add layers.
# - Compile model and fit model on train data.
# - Predict and test model.
# - Evaluation for the Model.

# %% [markdown]
# **Importing Needed Liberies**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
from pathlib import Path
import os
from random import randint
from sklearn import metrics
from sklearn.metrics import confusion_matrix
from sklearn.metrics import f1_score

# Tensorflow and Keras
from keras import models
from keras.layers import Conv2D, Dense,MaxPooling2D, Flatten, Dropout, BatchNormalization, MaxPool2D
import keras.preprocessing  as kp
from keras.preprocessing.image import ImageDataGenerator
from keras import regularizers
from keras import optimizers
from keras.callbacks import ModelCheckpoint

from keras.datasets import cifar10
from keras.models import Sequential
import tensorflow as tf
from keras.utils import np_utils

# %%
# Disable warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Load Datasets

# %%
train_path = '../input/malimg-after/malimg_dataset_after/train'
valid_path = '../input/malimg-after/malimg_dataset_after/val'
test_path = '../input/malimg-after/malimg_dataset_after/test'

# %%
train_df = ImageDataGenerator().flow_from_directory(directory=train_path, target_size=(128,128), 
                                                   batch_size=64,color_mode="rgb")
valid_df = ImageDataGenerator().flow_from_directory(directory=valid_path, target_size=(128,128), 
                                                   batch_size=64,color_mode="rgb")
valid_df = ImageDataGenerator().flow_from_directory(directory=test_path, target_size=(128,128), 
                                                   batch_size=64,color_mode="rgb")
# Out:
# Found 7465 images belonging to 25 classes.
# Found 942 images belonging to 25 classes.
# Found 957 images belonging to 25 classes.

# %%
aug = ImageDataGenerator(rotation_range=10,  
                         zoom_range = 0.1, 
                         width_shift_range=0.1,  
                         height_shift_range=0.1, 
                         rescale=1.0/255.0)

gen_train = aug.flow_from_directory(train_path,
                                    batch_size =64,
                                    class_mode = 'categorical', 
                                    target_size = (128, 128))
# Out:
# Found 7465 images belonging to 25 classes.

# %%
gen_valid = aug.flow_from_directory(valid_path, 
                                    batch_size =64,
                                    class_mode = 'categorical', 
                                    target_size = (128, 128))
# Out:
# Found 942 images belonging to 25 classes.

# %%
gen_test = aug.flow_from_directory(test_path,
                                batch_size =64,
                                class_mode = 'categorical', 
                                target_size = (128, 128))
# Out:
# Found 957 images belonging to 25 classes.

# %%
# get images and label of images from training dataset use for display some of dataset.
imgs, labels = next(gen_train)

# %%
# create label dictionary to use it know the type of malware (model use index(number not text))
label_dict = {value:key for key, value in gen_train.class_indices.items()}

# %%
# create subplot for some sample of train data.
fig, ax = plt.subplots(4,4,figsize=(10,10))

# loop on new image predict and display.
for row in range(16):
    i = row//4
    j = row%4
    rand_index = randint(0, labels.shape[0]-1)
    ax[i, j].imshow(imgs[rand_index])
    ax[i, j].set_title(label_dict[np.where(labels[rand_index]!=0)[0][0]])
    ax[i, j].axis('off')

plt.show()

# %% [markdown]
# ### CNN layers explain?
#
# - **Convolutional layer**: A convolution is a mathematical term that describes a dot product multiply between two sets of elements array of image and kernel array.
#
# - **MaxPooling layer**: Pooling is required to down sample the detection of features in feature maps, reduce the noise that happened from Convolutional Layers.
#
# - **Flatten layer**: Takes an input shape and flattens the input image data into a one-dimension Dense Layer:
#
# - **Dense Layer**: Fully connected layer, one dimension used in the last step in CNN.
#
# - **Batch Normalization layer**:
#     - Advantage of Batch Normalization layers: Makes sure that weights within the network do not become imbalanced with extreme values (reduce the ability of outlying large weights that will over-influence the training process).
#     - Increase the training speed: reach with high accuracy in a smaller number of epochs.
#     - When we use it? Use after Convolution layers.
# - **Dropout**: add Dropout layers.
#     - Why we use Dropout layers? prevent overfitting on the training data.
#     - Found that the different between accuracy in train and test is reduced, so model is better with Dropout layer that make model more generalize.

# %%
# create CNN Sequential model.
model = Sequential()

# Convolutional Layer
model.add(Conv2D(filters=32, kernel_size=(3, 3),
                 input_shape=(128, 128, 3), activation='relu',
                 kernel_initializer='he_uniform', padding='same'))

# BatchNormalization use to 
model.add(BatchNormalization())
model.add(Conv2D(filters=32, kernel_size=(3, 3), 
                 kernel_initializer='he_uniform',
                 activation='relu', padding='same'))

model.add(BatchNormalization())
# Pooling layer
model.add(MaxPool2D(pool_size=(2, 2)))
# Dropout layers
model.add(Dropout(0.25))

model.add(Conv2D(filters=64, kernel_size=(3, 3),
                 kernel_initializer='he_uniform',
                 activation='relu', padding='same'))

model.add(BatchNormalization())
model.add(Conv2D(filters=64, kernel_size=(3, 3),
                 kernel_initializer='he_uniform',
                 activation='relu', padding='same'))

model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(filters=128, kernel_size=(3, 3),
                 kernel_initializer='he_uniform',
                 activation='relu', padding='same'))

model.add(BatchNormalization())

model.add(Conv2D(filters=128, kernel_size=(3, 3),
                 kernel_initializer='he_uniform',
                 activation='relu', padding='same'))

model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(128, activation='relu', kernel_initializer='he_uniform',))
model.add(Dropout(0.25))
model.add(Dense(25, activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 128, 128, 32)      896
# _________________________________________________________________
# batch_normalization (BatchNo (None, 128, 128, 32)      128
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 128, 128, 32)      9248
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 128, 128, 32)      128
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 64, 64, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 64, 64, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 64, 64, 64)        18496
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 64, 64, 64)        256
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 64, 64, 64)        36928
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 64, 64, 64)        256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 32, 32, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32, 32, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 32, 32, 128)       73856
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 32, 32, 128)       512
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 32, 32, 128)       147584
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 32, 32, 128)       512
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 16, 16, 128)       0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 16, 16, 128)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 32768)             0
# _________________________________________________________________
# dense (Dense)                (None, 128)               4194432
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 25)                3225
# =================================================================
# Total params: 4,486,457
# Trainable params: 4,485,561
# Non-trainable params: 896
# _________________________________________________________________

# %% [markdown]
# ### Compile model and fit model on train data.

# %%
# compile model and create callback list use to train model.
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# use to early stop model before finish epoch to protect model from overfitting.
early_stop = tf.keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True)

# use to store best epoch weights for model to can use it to predict test dataset
checkpoint = tf.keras.callbacks.ModelCheckpoint("weights.hdf5",
                                                 monitor='val_accuracy',
                                                 verbose=1,
                                                 save_best_only=True)

reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_accuracy', verbose=1)
# check if need to add early stop to callback list or not.
call_backs = [early_stop, checkpoint, reduce_lr]

# %%
history = model.fit(gen_train, validation_data=gen_valid, 
                    epochs=25, batch_size=128, callbacks=call_backs)
# Out:
# Epoch 1/25
# 117/117 [==============================] - 132s 1s/step - loss: 3.1174 - accuracy: 0.4019 - val_loss: 4.6260 - val_accuracy: 0.1720
#
# Epoch 00001: val_accuracy improved from -inf to 0.17197, saving model to weights.hdf5
# Epoch 2/25
# 117/117 [==============================] - 78s 664ms/step - loss: 1.3925 - accuracy: 0.5719 - val_loss: 6.7442 - val_accuracy: 0.1815
#
# Epoch 00002: val_accuracy improved from 0.17197 to 0.18153, saving model to weights.hdf5
# Epoch 3/25
# 117/117 [==============================] - 78s 666ms/step - loss: 1.1427 - accuracy: 0.6497 - val_loss: 4.9557 - val_accuracy: 0.2006
#
# Epoch 00003: val_accuracy improved from 0.18153 to 0.20064, saving model to weights.hdf5
# Epoch 4/25
# 117/117 [==============================] - 77s 662ms/step - loss: 0.9138 - accuracy: 0.7175 - val_loss: 6.1331 - val_accuracy: 0.2665
#
# Epoch 00004: val_accuracy improved from 0.20064 to 0.26645, saving model to weights.hdf5
# Epoch 5/25
# 117/117 [==============================] - 77s 657ms/step - loss: 0.7836 - accuracy: 0.7512 - val_loss: 2.0988 - val_accuracy: 0.5340
#
# Epoch 00005: val_accuracy improved from 0.26645 to 0.53397, saving model to weights.hdf5
# Epoch 6/25
# 117/117 [==============================] - 77s 660ms/step - loss: 0.7220 - accuracy: 0.7780 - val_loss: 1.0943 - val_accuracy: 0.7389
#
# Epoch 00006: val_accuracy improved from 0.53397 to 0.73885, saving model to weights.hdf5
# Epoch 7/25
# 117/117 [==============================] - 78s 664ms/step - loss: 0.5961 - accuracy: 0.8099 - val_loss: 0.4271 - val_accuracy: 0.8885
#
# Epoch 00007: val_accuracy improved from 0.73885 to 0.88854, saving model to weights.hdf5
# Epoch 8/25
# 117/117 [==============================] - 76s 653ms/step - loss: 0.5362 - accuracy: 0.8313 - val_loss: 0.3703 - val_accuracy: 0.8896
#
# Epoch 00008: val_accuracy improved from 0.88854 to 0.88960, saving model to weights.hdf5
# Epoch 9/25
# 117/117 [==============================] - 77s 654ms/step - loss: 0.4564 - accuracy: 0.8563 - val_loss: 0.6554 - val_accuracy: 0.7930
#
# Epoch 00009: val_accuracy did not improve from 0.88960
# Epoch 10/25
# 117/117 [==============================] - 77s 658ms/step - loss: 0.4158 - accuracy: 0.8650 - val_loss: 0.2657 - val_accuracy: 0.9257
#
# Epoch 00010: val_accuracy improved from 0.88960 to 0.92569, saving model to weights.hdf5
# Epoch 11/25
# 117/117 [==============================] - 77s 657ms/step - loss: 0.3578 - accuracy: 0.8835 - val_loss: 0.2527 - val_accuracy: 0.9278
#
# Epoch 00011: val_accuracy improved from 0.92569 to 0.92781, saving model to weights.hdf5
# Epoch 12/25
# 117/117 [==============================] - 77s 659ms/step - loss: 0.3863 - accuracy: 0.8766 - val_loss: 0.3801 - val_accuracy: 0.8811
#
# Epoch 00012: val_accuracy did not improve from 0.92781
# Epoch 13/25
# 117/117 [==============================] - 77s 656ms/step - loss: 0.3400 - accuracy: 0.8865 - val_loss: 0.8239 - val_accuracy: 0.8588
#
# Epoch 00013: val_accuracy did not improve from 0.92781
# Epoch 14/25
# 117/117 [==============================] - 77s 655ms/step - loss: 0.3428 - accuracy: 0.8922 - val_loss: 0.2188 - val_accuracy: 0.9363
#
# Epoch 00014: val_accuracy improved from 0.92781 to 0.93631, saving model to weights.hdf5
# Epoch 15/25
# 117/117 [==============================] - 77s 655ms/step - loss: 0.2999 - accuracy: 0.9007 - val_loss: 0.9522 - val_accuracy: 0.8482
#
# Epoch 00015: val_accuracy did not improve from 0.93631
# Epoch 16/25
# 117/117 [==============================] - 76s 653ms/step - loss: 0.3027 - accuracy: 0.9017 - val_loss: 0.3639 - val_accuracy: 0.9321
#
# Epoch 00016: val_accuracy did not improve from 0.93631
# Epoch 17/25
# 117/117 [==============================] - 76s 650ms/step - loss: 0.2670 - accuracy: 0.9082 - val_loss: 0.1225 - val_accuracy: 0.9639
#
# Epoch 00017: val_accuracy improved from 0.93631 to 0.96391, saving model to weights.hdf5
# Epoch 18/25
# 117/117 [==============================] - 76s 652ms/step - loss: 0.2575 - accuracy: 0.9106 - val_loss: 0.3600 - val_accuracy: 0.9130
#
# Epoch 00018: val_accuracy did not improve from 0.96391
# Epoch 19/25
# 117/117 [==============================] - 76s 647ms/step - loss: 0.2636 - accuracy: 0.9144 - val_loss: 0.4569 - val_accuracy: 0.8737
#
# Epoch 00019: val_accuracy did not improve from 0.96391
# Epoch 20/25
# 117/117 [==============================] - 76s 648ms/step - loss: 0.2455 - accuracy: 0.9195 - val_loss: 0.7689 - val_accuracy: 0.8800
#
# Epoch 00020: val_accuracy did not improve from 0.96391
# Epoch 21/25
# 117/117 [==============================] - 76s 647ms/step - loss: 0.2260 - accuracy: 0.9223 - val_loss: 0.3226 - val_accuracy: 0.9257
#
# Epoch 00021: val_accuracy did not improve from 0.96391
# Epoch 22/25
# 117/117 [==============================] - 76s 650ms/step - loss: 0.2256 - accuracy: 0.9244 - val_loss: 0.4143 - val_accuracy: 0.9236
#
# Epoch 00022: val_accuracy did not improve from 0.96391
# Epoch 23/25
# 117/117 [==============================] - 76s 650ms/step - loss: 0.2215 - accuracy: 0.9254 - val_loss: 0.1240 - val_accuracy: 0.9575
#
# Epoch 00023: val_accuracy did not improve from 0.96391
# Epoch 24/25
# 117/117 [==============================] - 76s 650ms/step - loss: 0.1996 - accuracy: 0.9282 - val_loss: 0.6167 - val_accuracy: 0.9151
#
# Epoch 00024: val_accuracy did not improve from 0.96391
# Epoch 25/25
# 117/117 [==============================] - 76s 651ms/step - loss: 0.2236 - accuracy: 0.9234 - val_loss: 0.2407 - val_accuracy: 0.9448
#
# Epoch 00025: val_accuracy did not improve from 0.96391

# %% [markdown]
# ### Predict and test model.

# %%
# calculate test accuracy and loss.
test_loss, test_acc = model.evaluate_generator(gen_test, steps=50)
print('Test Accuracy:', round(test_acc*100,2),"%")
print('Test Loss:',test_loss)
# Out:
# Test Accuracy: 95.82 %
# Test Loss: 0.1400752067565918

# %%
# restor parameter for best epoch and predict test data.
model.load_weights('./weights.hdf5')

# %%
imgs, labels = next(gen_test)

# %%
# create subplot for outside image.
fig, ax = plt.subplots(4,4,figsize=(12,10))

# loop on new image predict and display.
for row in range(16):
    i = row//4
    j = row%4
    rand_index = randint(0, labels.shape[0]-1)
    ax[i, j].imshow(imgs[rand_index])
    label_key = np.argmax(model.predict(np.expand_dims(imgs[rand_index],axis=0)))
    ax[i, j].set_title(label_dict[label_key]+" / "+label_dict[np.where(labels[rand_index]!=0)[0][0]])
    ax[i, j].axis('off')

plt.show()

# %% [markdown]
# ### Evaluate the model.

# %% [markdown]
# **Loss With epochs for Train and Validation Data**

# %%
sns.set()
# plot loss function for train and validation.
plt.title('loss and validation loss with epochs', 
          fontsize=16)

plt.plot(history.history['loss'],
         marker='o',
         color="green",
         label="loss")

plt.plot(history.history['val_loss'],
         marker='o',
         color="orange", 
         label="val_loss")

plt.legend()
plt.show()

# %% [markdown]
# **Accuracy With epochs for Train and Validation Data**

# %%
# plot accuracy for train and validation data.
plt.title('accuracy and validation accuracy with epochs',
          fontsize=16)

plt.plot(history.history['accuracy'],
         marker='o',
         color="green",
         label="accuracy")

plt.plot(history.history['val_accuracy'],
         marker='o',
         color="orange",
         label="val_accuracy")

plt.legend()
plt.show()

# %% [markdown]
# **ROC Metrics**

# %%
x, y = gen_train.next()
prediction = model.predict(x)

classes = np.argmax(prediction, axis=-1)
true_label1 = np.argmax(y, axis=-1)

y_true = np.array(true_label1)

y_pred = np.array(classes)
fpr, tpr, thresholds = metrics.roc_curve(y_true, y_pred, pos_label=9)
roc_auc = metrics.auc(fpr, tpr)


plt.figure()
lw = 2
plt.plot(fpr, tpr, color='darkorange',
        lw=lw, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic (ROC)')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# **Confusion Matrix**

# %%
cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(8,8))
plt.title("Confusion Matrix",fontsize=16)
sns.heatmap(cm, fmt='d', cmap='viridis', annot = True, square=True, cbar=False)
plt.show()

# %% [markdown]
# **F1 Score**

# %%
# F1 Score = 2 * ((Precision * Recall)/ (Precision + Recall))
f1 = f1_score(y_true, y_pred, average='macro')
print('F1 score: %f' % f1)
# Out:
# F1 score: 0.852837

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
recall_score(y_true, y_pred,average="macro")*100
# Out:
# 87.5

# %%
precision_score(y_true, y_pred, average="macro")*100
# Out:
# 84.11458333333334

# %% [markdown]
# ### Thanks
