# %%
color=2

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import time
import subprocess
import numpy
import scipy.misc
import os
import imageio
import array
import glob
import cv2


def is_pe(fileName):
    parts = os.path.splitext(fileName) # tách tập tin thành phần cơ sở và mở rộng
    extension = parts[-1] # Lấy phần mở rộng
    return extension.lower() in [".exe", ".dll", ".ocx", ".sys", ".ime", ".cpl", ".bpl", ".ime", ".tlb", ".ocx", ".res", ".ax"] # kiểm tra phần mở rộng


def generate_image(input, output, fileName):

    out_file = os.path.splitext(os.path.basename(fileName))[0] + '.png' # lấy tên cơ sở của tệp tin PE (phần trước dấu chấm .) và thêm phần mở rộng .png để tạo tên tệp tin hình ảnh đầu ra.
    out_file_full = os.path.join(output, out_file) # tạo đường dẫn của hình ảnh đầu ra.
    input_file_path = os.path.join(input, fileName) # đường dẫn chứa tập PE

    if is_pe(fileName):
        open_pe = open(input_file_path, 'rb') # mở tệp tin để đọc trong chế độ nhị phân.
        len_pe = os.path.getsize(input_file_path)  #  lấy kích thước của tệp tin (độ dài tệp tin theo byte).
        width = 256 #chiều rộng ảnh
        rem = len_pe % width #kích thước dư
        a = array.array("B")  # tạo một mảng dữ liệu kiểu uint8 để lưu trữ thông tin hình ảnh
        a.fromfile(open_pe, len_pe - rem)#đọc nội dung tệp tin PE vào mảng dữ liệu hình ảnh, bỏ qua phần còn lại của tệp tin nếu kích thước không chia hết cho 256 byte.
        open_pe.close()
        g = numpy.reshape(a, (len(a) // width, width))# chuyển đổi mảng dữ liệu hình ảnh thành ma trận hình ảnh, có chiều rộng bằng 256 pixel.
        g = numpy.uint8(g) #chuyển đổi loại dữ liệu của ma trận hình ảnh thành uint8
        g = numpy.stack([g, g, g], axis=2) #chuyển đổi mảng dữ liệu thành mảng ba chiều

        if color==0:
          g = cv2.cvtColor(g, cv2.COLOR_BGR2LAB)
        elif color==1:
          g = cv2.cvtColor(g, cv2.COLOR_BGR2HSV)
        elif color==2:
          g = cv2.cvtColor(g, cv2.COLOR_BGR2HLS)
        else:
          g =g

        cv2.imwrite(out_file_full, g)
    else:
        print("not pe")



def convert_binary_to_img(input, output):

    count = 0
    files = os.listdir(input)# danh sách các tệp trong input
    print(files)
    for filename in files:
        try:
            generate_image(input, output, filename)

        except:
             print('error', filename)

# %%
input = '/content/drive/MyDrive/IE105/model/input'
output = '/content/drive/MyDrive/IE105/model/output'

start_time = time.time()

convert_binary_to_img(input, output)

end_time = time.time()

time_run = end_time-start_time
# Out:
# ['webengine4.dll', 'splwow64.exe', 'hhh.exe', 'abc.exe']

# %%
time_run
# Out:
# 0.17123746871948242

# %%
import cv2
import os

# Tạo thư mục mới để lưu trữ các ảnh màu đỏ
output_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset_after/train/Allaple.A'
os.makedirs(output_dir, exist_ok=True)

# Liệt kê tất cả các tệp hình ảnh trong thư mục gốc
input_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset/train/Allaple.A'
files = os.listdir(input_dir)

# Lặp qua từng tệp hình ảnh
for file in files:

    # Lấy tên tệp và phần mở rộng
    filename, ext = os.path.splitext(file)

    # Kiểm tra xem tệp có phải là ảnh trắng đen hay không
    if ext.lower() in [".jpg", ".jpeg", ".png"]:

        # Tải hình ảnh
        img = cv2.imread(os.path.join(input_dir, file))

        img = cv2.cvtColor( img, cv2.COLOR_BGR2HSV)

        # Lưu ảnh màu đỏ đã chuyển đổi
        cv2.imwrite(os.path.join(output_dir, file), img)

# %%
# Tạo thư mục mới để lưu trữ các ảnh màu đỏ
output_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset_after/train/Adialer.C'
os.makedirs(output_dir, exist_ok=True)

# Liệt kê tất cả các tệp hình ảnh trong thư mục gốc
input_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset/train/Adialer.C'
files = os.listdir(input_dir)

# Lặp qua từng tệp hình ảnh
for file in files:

    # Lấy tên tệp và phần mở rộng
    filename, ext = os.path.splitext(file)

    # Kiểm tra xem tệp có phải là ảnh trắng đen hay không
    if ext.lower() in [".jpg", ".jpeg", ".png"]:

        # Tải hình ảnh
        img = cv2.imread(os.path.join(input_dir, file))

        img = cv2.cvtColor( img, cv2.COLOR_BGR2HSV)

        # Lưu ảnh màu đỏ đã chuyển đổi
        cv2.imwrite(os.path.join(output_dir, file), img)

# %%
# Tạo thư mục mới để lưu trữ các ảnh màu đỏ
output_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset_after/train/Agent.FYI'
os.makedirs(output_dir, exist_ok=True)

# Liệt kê tất cả các tệp hình ảnh trong thư mục gốc
input_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset/train/Agent.FYI'
files = os.listdir(input_dir)

# Lặp qua từng tệp hình ảnh
for file in files:

    # Lấy tên tệp và phần mở rộng
    filename, ext = os.path.splitext(file)

    # Kiểm tra xem tệp có phải là ảnh trắng đen hay không
    if ext.lower() in [".jpg", ".jpeg", ".png"]:

        # Tải hình ảnh
        img = cv2.imread(os.path.join(input_dir, file))

        img = cv2.cvtColor( img, cv2.COLOR_BGR2HSV)

        # Lưu ảnh màu đỏ đã chuyển đổi
        cv2.imwrite(os.path.join(output_dir, file), img)

# %%
# Tạo thư mục mới để lưu trữ các ảnh màu đỏ
output_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset_after/train/Allaple.L'
os.makedirs(output_dir, exist_ok=True)

# Liệt kê tất cả các tệp hình ảnh trong thư mục gốc
input_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset/train/Allaple.L'
files = os.listdir(input_dir)

# Lặp qua từng tệp hình ảnh
for file in files:

    # Lấy tên tệp và phần mở rộng
    filename, ext = os.path.splitext(file)

    # Kiểm tra xem tệp có phải là ảnh trắng đen hay không
    if ext.lower() in [".jpg", ".jpeg", ".png"]:

        # Tải hình ảnh
        img = cv2.imread(os.path.join(input_dir, file))

        img = cv2.cvtColor( img, cv2.COLOR_BGR2HSV)

        # Lưu ảnh màu đỏ đã chuyển đổi
        cv2.imwrite(os.path.join(output_dir, file), img)

# %%
# Tạo thư mục mới để lưu trữ các ảnh màu đỏ
output_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset_after/train/Alueron.gen!J'
os.makedirs(output_dir, exist_ok=True)

# Liệt kê tất cả các tệp hình ảnh trong thư mục gốc
input_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset/train/Alueron.gen!J'
files = os.listdir(input_dir)

# Lặp qua từng tệp hình ảnh
for file in files:

    # Lấy tên tệp và phần mở rộng
    filename, ext = os.path.splitext(file)

    # Kiểm tra xem tệp có phải là ảnh trắng đen hay không
    if ext.lower() in [".jpg", ".jpeg", ".png"]:

        # Tải hình ảnh
        img = cv2.imread(os.path.join(input_dir, file))

        img = cv2.cvtColor( img, cv2.COLOR_BGR2HSV)

        # Lưu ảnh màu đỏ đã chuyển đổi
        cv2.imwrite(os.path.join(output_dir, file), img)

# %%
# Tạo thư mục mới để lưu trữ các ảnh màu đỏ
output_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset_after/train/Autorun.K'
os.makedirs(output_dir, exist_ok=True)

# Liệt kê tất cả các tệp hình ảnh trong thư mục gốc
input_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset/train/Autorun.K'
files = os.listdir(input_dir)

# Lặp qua từng tệp hình ảnh
for file in files:

    # Lấy tên tệp và phần mở rộng
    filename, ext = os.path.splitext(file)

    # Kiểm tra xem tệp có phải là ảnh trắng đen hay không
    if ext.lower() in [".jpg", ".jpeg", ".png"]:

        # Tải hình ảnh
        img = cv2.imread(os.path.join(input_dir, file))

        img = cv2.cvtColor( img, cv2.COLOR_BGR2HSV)

        # Lưu ảnh màu đỏ đã chuyển đổi
        cv2.imwrite(os.path.join(output_dir, file), img)

# %%
# Tạo thư mục mới để lưu trữ các ảnh màu đỏ
output_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset_after/train/C2LOP.P'
os.makedirs(output_dir, exist_ok=True)

# Liệt kê tất cả các tệp hình ảnh trong thư mục gốc
input_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset/train/C2LOP.P'
files = os.listdir(input_dir)

# Lặp qua từng tệp hình ảnh
for file in files:

    # Lấy tên tệp và phần mở rộng
    filename, ext = os.path.splitext(file)

    # Kiểm tra xem tệp có phải là ảnh trắng đen hay không
    if ext.lower() in [".jpg", ".jpeg", ".png"]:

        # Tải hình ảnh
        img = cv2.imread(os.path.join(input_dir, file))

        img = cv2.cvtColor( img, cv2.COLOR_BGR2HSV)

        # Lưu ảnh màu đỏ đã chuyển đổi
        cv2.imwrite(os.path.join(output_dir, file), img)

# %%
# Tạo thư mục mới để lưu trữ các ảnh màu đỏ
output_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset_after/train/C2LOP.gen!g'
os.makedirs(output_dir, exist_ok=True)

# Liệt kê tất cả các tệp hình ảnh trong thư mục gốc
input_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset/train/C2LOP.gen!g'
files = os.listdir(input_dir)

# Lặp qua từng tệp hình ảnh
for file in files:

    # Lấy tên tệp và phần mở rộng
    filename, ext = os.path.splitext(file)

    # Kiểm tra xem tệp có phải là ảnh trắng đen hay không
    if ext.lower() in [".jpg", ".jpeg", ".png"]:

        # Tải hình ảnh
        img = cv2.imread(os.path.join(input_dir, file))

        img = cv2.cvtColor( img, cv2.COLOR_BGR2HSV)

        # Lưu ảnh màu đỏ đã chuyển đổi
        cv2.imwrite(os.path.join(output_dir, file), img)

# %%
# Tạo thư mục mới để lưu trữ các ảnh màu đỏ
output_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset_after/train/Dialplatform.B'
os.makedirs(output_dir, exist_ok=True)

# Liệt kê tất cả các tệp hình ảnh trong thư mục gốc
input_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset/train/Dialplatform.B'
files = os.listdir(input_dir)

# Lặp qua từng tệp hình ảnh
for file in files:

    # Lấy tên tệp và phần mở rộng
    filename, ext = os.path.splitext(file)

    # Kiểm tra xem tệp có phải là ảnh trắng đen hay không
    if ext.lower() in [".jpg", ".jpeg", ".png"]:

        # Tải hình ảnh
        img = cv2.imread(os.path.join(input_dir, file))

        img = cv2.cvtColor( img, cv2.COLOR_BGR2HSV)

        # Lưu ảnh màu đỏ đã chuyển đổi
        cv2.imwrite(os.path.join(output_dir, file), img)

# %%
# Tạo thư mục mới để lưu trữ các ảnh màu đỏ
output_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset_after/train/Dontovo.A'
os.makedirs(output_dir, exist_ok=True)

# Liệt kê tất cả các tệp hình ảnh trong thư mục gốc
input_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset/train/Dontovo.A'
files = os.listdir(input_dir)

# Lặp qua từng tệp hình ảnh
for file in files:

    # Lấy tên tệp và phần mở rộng
    filename, ext = os.path.splitext(file)

    # Kiểm tra xem tệp có phải là ảnh trắng đen hay không
    if ext.lower() in [".jpg", ".jpeg", ".png"]:

        # Tải hình ảnh
        img = cv2.imread(os.path.join(input_dir, file))

        img = cv2.cvtColor( img, cv2.COLOR_BGR2HSV)

        # Lưu ảnh màu đỏ đã chuyển đổi
        cv2.imwrite(os.path.join(output_dir, file), img)

# %%
# Tạo thư mục mới để lưu trữ các ảnh màu đỏ
output_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset_after/train/Fakerean'
os.makedirs(output_dir, exist_ok=True)

# Liệt kê tất cả các tệp hình ảnh trong thư mục gốc
input_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset/train/Fakerean'
files = os.listdir(input_dir)

# Lặp qua từng tệp hình ảnh
for file in files:

    # Lấy tên tệp và phần mở rộng
    filename, ext = os.path.splitext(file)

    # Kiểm tra xem tệp có phải là ảnh trắng đen hay không
    if ext.lower() in [".jpg", ".jpeg", ".png"]:

        # Tải hình ảnh
        img = cv2.imread(os.path.join(input_dir, file))

        img = cv2.cvtColor( img, cv2.COLOR_BGR2HSV)

        # Lưu ảnh màu đỏ đã chuyển đổi
        cv2.imwrite(os.path.join(output_dir, file), img)

# %%
# Tạo thư mục mới để lưu trữ các ảnh màu đỏ
output_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset_after/train/Instantaccess'
os.makedirs(output_dir, exist_ok=True)

# Liệt kê tất cả các tệp hình ảnh trong thư mục gốc
input_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset/train/Instantaccess'
files = os.listdir(input_dir)

# Lặp qua từng tệp hình ảnh
for file in files:

    # Lấy tên tệp và phần mở rộng
    filename, ext = os.path.splitext(file)

    # Kiểm tra xem tệp có phải là ảnh trắng đen hay không
    if ext.lower() in [".jpg", ".jpeg", ".png"]:

        # Tải hình ảnh
        img = cv2.imread(os.path.join(input_dir, file))

        img = cv2.cvtColor( img, cv2.COLOR_BGR2HSV)

        # Lưu ảnh màu đỏ đã chuyển đổi
        cv2.imwrite(os.path.join(output_dir, file), img)

# %%
# Tạo thư mục mới để lưu trữ các ảnh màu đỏ
output_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset_after/train/Lolyda.AA1'
os.makedirs(output_dir, exist_ok=True)

# Liệt kê tất cả các tệp hình ảnh trong thư mục gốc
input_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset/train/Lolyda.AA1'
files = os.listdir(input_dir)

# Lặp qua từng tệp hình ảnh
for file in files:

    # Lấy tên tệp và phần mở rộng
    filename, ext = os.path.splitext(file)

    # Kiểm tra xem tệp có phải là ảnh trắng đen hay không
    if ext.lower() in [".jpg", ".jpeg", ".png"]:

        # Tải hình ảnh
        img = cv2.imread(os.path.join(input_dir, file))

        img = cv2.cvtColor( img, cv2.COLOR_BGR2HSV)

        # Lưu ảnh màu đỏ đã chuyển đổi
        cv2.imwrite(os.path.join(output_dir, file), img)

# %%
# Tạo thư mục mới để lưu trữ các ảnh màu đỏ
output_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset_after/train/Lolyda.AA2'
os.makedirs(output_dir, exist_ok=True)

# Liệt kê tất cả các tệp hình ảnh trong thư mục gốc
input_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset/train/Lolyda.AA2'
files = os.listdir(input_dir)

# Lặp qua từng tệp hình ảnh
for file in files:

    # Lấy tên tệp và phần mở rộng
    filename, ext = os.path.splitext(file)

    # Kiểm tra xem tệp có phải là ảnh trắng đen hay không
    if ext.lower() in [".jpg", ".jpeg", ".png"]:

        # Tải hình ảnh
        img = cv2.imread(os.path.join(input_dir, file))

        img = cv2.cvtColor( img, cv2.COLOR_BGR2HSV)

        # Lưu ảnh màu đỏ đã chuyển đổi
        cv2.imwrite(os.path.join(output_dir, file), img)

# %%
# Tạo thư mục mới để lưu trữ các ảnh màu đỏ
output_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset_after/train/Lolyda.AA3'
os.makedirs(output_dir, exist_ok=True)

# Liệt kê tất cả các tệp hình ảnh trong thư mục gốc
input_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset/train/Lolyda.AA3'
files = os.listdir(input_dir)

# Lặp qua từng tệp hình ảnh
for file in files:

    # Lấy tên tệp và phần mở rộng
    filename, ext = os.path.splitext(file)

    # Kiểm tra xem tệp có phải là ảnh trắng đen hay không
    if ext.lower() in [".jpg", ".jpeg", ".png"]:

        # Tải hình ảnh
        img = cv2.imread(os.path.join(input_dir, file))

        img = cv2.cvtColor( img, cv2.COLOR_BGR2HSV)

        # Lưu ảnh màu đỏ đã chuyển đổi
        cv2.imwrite(os.path.join(output_dir, file), img)

# %%
# Tạo thư mục mới để lưu trữ các ảnh màu đỏ
output_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset_after/train/Lolyda.AT'
os.makedirs(output_dir, exist_ok=True)

# Liệt kê tất cả các tệp hình ảnh trong thư mục gốc
input_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset/train/Lolyda.AT'
files = os.listdir(input_dir)

# Lặp qua từng tệp hình ảnh
for file in files:

    # Lấy tên tệp và phần mở rộng
    filename, ext = os.path.splitext(file)

    # Kiểm tra xem tệp có phải là ảnh trắng đen hay không
    if ext.lower() in [".jpg", ".jpeg", ".png"]:

        # Tải hình ảnh
        img = cv2.imread(os.path.join(input_dir, file))

        img = cv2.cvtColor( img, cv2.COLOR_BGR2HSV)

        # Lưu ảnh màu đỏ đã chuyển đổi
        cv2.imwrite(os.path.join(output_dir, file), img)

# %%
# Tạo thư mục mới để lưu trữ các ảnh màu đỏ
output_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset_after/train/Malex.gen!J'
os.makedirs(output_dir, exist_ok=True)

# Liệt kê tất cả các tệp hình ảnh trong thư mục gốc
input_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset/train/Malex.gen!J'
files = os.listdir(input_dir)

# Lặp qua từng tệp hình ảnh
for file in files:

    # Lấy tên tệp và phần mở rộng
    filename, ext = os.path.splitext(file)

    # Kiểm tra xem tệp có phải là ảnh trắng đen hay không
    if ext.lower() in [".jpg", ".jpeg", ".png"]:

        # Tải hình ảnh
        img = cv2.imread(os.path.join(input_dir, file))

        img = cv2.cvtColor( img, cv2.COLOR_BGR2HSV)

        # Lưu ảnh màu đỏ đã chuyển đổi
        cv2.imwrite(os.path.join(output_dir, file), img)

# %%
# Tạo thư mục mới để lưu trữ các ảnh màu đỏ
output_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset_after/train/Obfuscator.AD'
os.makedirs(output_dir, exist_ok=True)

# Liệt kê tất cả các tệp hình ảnh trong thư mục gốc
input_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset/train/Obfuscator.AD'
files = os.listdir(input_dir)

# Lặp qua từng tệp hình ảnh
for file in files:

    # Lấy tên tệp và phần mở rộng
    filename, ext = os.path.splitext(file)

    # Kiểm tra xem tệp có phải là ảnh trắng đen hay không
    if ext.lower() in [".jpg", ".jpeg", ".png"]:

        # Tải hình ảnh
        img = cv2.imread(os.path.join(input_dir, file))

        img = cv2.cvtColor( img, cv2.COLOR_BGR2HSV)

        # Lưu ảnh màu đỏ đã chuyển đổi
        cv2.imwrite(os.path.join(output_dir, file), img)

# %%
# Tạo thư mục mới để lưu trữ các ảnh màu đỏ
output_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset_after/train/Rbot!gen'
os.makedirs(output_dir, exist_ok=True)

# Liệt kê tất cả các tệp hình ảnh trong thư mục gốc
input_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset/train/Rbot!gen'
files = os.listdir(input_dir)

# Lặp qua từng tệp hình ảnh
for file in files:

    # Lấy tên tệp và phần mở rộng
    filename, ext = os.path.splitext(file)

    # Kiểm tra xem tệp có phải là ảnh trắng đen hay không
    if ext.lower() in [".jpg", ".jpeg", ".png"]:

        # Tải hình ảnh
        img = cv2.imread(os.path.join(input_dir, file))

        img = cv2.cvtColor( img, cv2.COLOR_BGR2HSV)

        # Lưu ảnh màu đỏ đã chuyển đổi
        cv2.imwrite(os.path.join(output_dir, file), img)

# %%
# Tạo thư mục mới để lưu trữ các ảnh màu đỏ
output_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset_after/train/Skintrim.N'
os.makedirs(output_dir, exist_ok=True)

# Liệt kê tất cả các tệp hình ảnh trong thư mục gốc
input_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset/train/Skintrim.N'
files = os.listdir(input_dir)

# Lặp qua từng tệp hình ảnh
for file in files:

    # Lấy tên tệp và phần mở rộng
    filename, ext = os.path.splitext(file)

    # Kiểm tra xem tệp có phải là ảnh trắng đen hay không
    if ext.lower() in [".jpg", ".jpeg", ".png"]:

        # Tải hình ảnh
        img = cv2.imread(os.path.join(input_dir, file))

        img = cv2.cvtColor( img, cv2.COLOR_BGR2HSV)

        # Lưu ảnh màu đỏ đã chuyển đổi
        cv2.imwrite(os.path.join(output_dir, file), img)

# %%
# Tạo thư mục mới để lưu trữ các ảnh màu đỏ
output_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset_after/train/Swizzor.gen!E'
os.makedirs(output_dir, exist_ok=True)

# Liệt kê tất cả các tệp hình ảnh trong thư mục gốc
input_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset/train/Swizzor.gen!E'
files = os.listdir(input_dir)

# Lặp qua từng tệp hình ảnh
for file in files:

    # Lấy tên tệp và phần mở rộng
    filename, ext = os.path.splitext(file)

    # Kiểm tra xem tệp có phải là ảnh trắng đen hay không
    if ext.lower() in [".jpg", ".jpeg", ".png"]:

        # Tải hình ảnh
        img = cv2.imread(os.path.join(input_dir, file))

        img = cv2.cvtColor( img, cv2.COLOR_BGR2HSV)

        # Lưu ảnh màu đỏ đã chuyển đổi
        cv2.imwrite(os.path.join(output_dir, file), img)

# %%
# Tạo thư mục mới để lưu trữ các ảnh màu đỏ
output_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset_after/train/Swizzor.gen!I'
os.makedirs(output_dir, exist_ok=True)

# Liệt kê tất cả các tệp hình ảnh trong thư mục gốc
input_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset/train/Swizzor.gen!I'
files = os.listdir(input_dir)

# Lặp qua từng tệp hình ảnh
for file in files:

    # Lấy tên tệp và phần mở rộng
    filename, ext = os.path.splitext(file)

    # Kiểm tra xem tệp có phải là ảnh trắng đen hay không
    if ext.lower() in [".jpg", ".jpeg", ".png"]:

        # Tải hình ảnh
        img = cv2.imread(os.path.join(input_dir, file))

        img = cv2.cvtColor( img, cv2.COLOR_BGR2HSV)

        # Lưu ảnh màu đỏ đã chuyển đổi
        cv2.imwrite(os.path.join(output_dir, file), img)

# %%
# Tạo thư mục mới để lưu trữ các ảnh màu đỏ
output_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset_after/train/VB.AT'
os.makedirs(output_dir, exist_ok=True)

# Liệt kê tất cả các tệp hình ảnh trong thư mục gốc
input_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset/train/VB.AT'
files = os.listdir(input_dir)

# Lặp qua từng tệp hình ảnh
for file in files:

    # Lấy tên tệp và phần mở rộng
    filename, ext = os.path.splitext(file)

    # Kiểm tra xem tệp có phải là ảnh trắng đen hay không
    if ext.lower() in [".jpg", ".jpeg", ".png"]:

        # Tải hình ảnh
        img = cv2.imread(os.path.join(input_dir, file))

        img = cv2.cvtColor( img, cv2.COLOR_BGR2HSV)

        # Lưu ảnh màu đỏ đã chuyển đổi
        cv2.imwrite(os.path.join(output_dir, file), img)

# %%
# Tạo thư mục mới để lưu trữ các ảnh màu đỏ
output_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset_after/train/Wintrim.BX'
os.makedirs(output_dir, exist_ok=True)

# Liệt kê tất cả các tệp hình ảnh trong thư mục gốc
input_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset/train/Wintrim.BX'
files = os.listdir(input_dir)

# Lặp qua từng tệp hình ảnh
for file in files:

    # Lấy tên tệp và phần mở rộng
    filename, ext = os.path.splitext(file)

    # Kiểm tra xem tệp có phải là ảnh trắng đen hay không
    if ext.lower() in [".jpg", ".jpeg", ".png"]:

        # Tải hình ảnh
        img = cv2.imread(os.path.join(input_dir, file))

        img = cv2.cvtColor( img, cv2.COLOR_BGR2HSV)

        # Lưu ảnh màu đỏ đã chuyển đổi
        cv2.imwrite(os.path.join(output_dir, file), img)

# %%
# Tạo thư mục mới để lưu trữ các ảnh màu đỏ
output_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset_after/train/Yuner.A'
os.makedirs(output_dir, exist_ok=True)

# Liệt kê tất cả các tệp hình ảnh trong thư mục gốc
input_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset/train/Yuner.A'
files = os.listdir(input_dir)

# Lặp qua từng tệp hình ảnh
for file in files:

    # Lấy tên tệp và phần mở rộng
    filename, ext = os.path.splitext(file)

    # Kiểm tra xem tệp có phải là ảnh trắng đen hay không
    if ext.lower() in [".jpg", ".jpeg", ".png"]:

        # Tải hình ảnh
        img = cv2.imread(os.path.join(input_dir, file))

        img = cv2.cvtColor( img, cv2.COLOR_BGR2HSV)

        # Lưu ảnh màu đỏ đã chuyển đổi
        cv2.imwrite(os.path.join(output_dir, file), img)

# %%
import cv2
import os

# Tạo thư mục mới để lưu trữ các ảnh màu đỏ
output_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset_after/test/Allaple.A'
os.makedirs(output_dir, exist_ok=True)

# Liệt kê tất cả các tệp hình ảnh trong thư mục gốc
input_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset/test/Allaple.A'
files = os.listdir(input_dir)

# Lặp qua từng tệp hình ảnh
for file in files:

    # Lấy tên tệp và phần mở rộng
    filename, ext = os.path.splitext(file)

    # Kiểm tra xem tệp có phải là ảnh trắng đen hay không
    if ext.lower() in [".jpg", ".jpeg", ".png"]:

        # Tải hình ảnh
        img = cv2.imread(os.path.join(input_dir, file))

        img = cv2.cvtColor( img, cv2.COLOR_BGR2HSV)

        # Lưu ảnh màu đỏ đã chuyển đổi
        cv2.imwrite(os.path.join(output_dir, file), img)

# %%
# Tạo thư mục mới để lưu trữ các ảnh màu đỏ
output_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset_after/test/Adialer.C'
os.makedirs(output_dir, exist_ok=True)

# Liệt kê tất cả các tệp hình ảnh trong thư mục gốc
input_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset/test/Adialer.C'
files = os.listdir(input_dir)

# Lặp qua từng tệp hình ảnh
for file in files:

    # Lấy tên tệp và phần mở rộng
    filename, ext = os.path.splitext(file)

    # Kiểm tra xem tệp có phải là ảnh trắng đen hay không
    if ext.lower() in [".jpg", ".jpeg", ".png"]:

        # Tải hình ảnh
        img = cv2.imread(os.path.join(input_dir, file))

        img = cv2.cvtColor( img, cv2.COLOR_BGR2HSV)

        # Lưu ảnh màu đỏ đã chuyển đổi
        cv2.imwrite(os.path.join(output_dir, file), img)

# %%
# Tạo thư mục mới để lưu trữ các ảnh màu đỏ
output_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset_after/test/Agent.FYI'
os.makedirs(output_dir, exist_ok=True)

# Liệt kê tất cả các tệp hình ảnh trong thư mục gốc
input_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset/test/Agent.FYI'
files = os.listdir(input_dir)

# Lặp qua từng tệp hình ảnh
for file in files:

    # Lấy tên tệp và phần mở rộng
    filename, ext = os.path.splitext(file)

    # Kiểm tra xem tệp có phải là ảnh trắng đen hay không
    if ext.lower() in [".jpg", ".jpeg", ".png"]:

        # Tải hình ảnh
        img = cv2.imread(os.path.join(input_dir, file))

        img = cv2.cvtColor( img, cv2.COLOR_BGR2HSV)

        # Lưu ảnh màu đỏ đã chuyển đổi
        cv2.imwrite(os.path.join(output_dir, file), img)

# %%
# Tạo thư mục mới để lưu trữ các ảnh màu đỏ
output_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset_after/test/Allaple.L'
os.makedirs(output_dir, exist_ok=True)

# Liệt kê tất cả các tệp hình ảnh trong thư mục gốc
input_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset/test/Allaple.L'
files = os.listdir(input_dir)

# Lặp qua từng tệp hình ảnh
for file in files:

    # Lấy tên tệp và phần mở rộng
    filename, ext = os.path.splitext(file)

    # Kiểm tra xem tệp có phải là ảnh trắng đen hay không
    if ext.lower() in [".jpg", ".jpeg", ".png"]:

        # Tải hình ảnh
        img = cv2.imread(os.path.join(input_dir, file))

        img = cv2.cvtColor( img, cv2.COLOR_BGR2HSV)

        # Lưu ảnh màu đỏ đã chuyển đổi
        cv2.imwrite(os.path.join(output_dir, file), img)

# %%
# Tạo thư mục mới để lưu trữ các ảnh màu đỏ
output_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset_after/test/Alueron.gen!J'
os.makedirs(output_dir, exist_ok=True)

# Liệt kê tất cả các tệp hình ảnh trong thư mục gốc
input_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset/test/Alueron.gen!J'
files = os.listdir(input_dir)

# Lặp qua từng tệp hình ảnh
for file in files:

    # Lấy tên tệp và phần mở rộng
    filename, ext = os.path.splitext(file)

    # Kiểm tra xem tệp có phải là ảnh trắng đen hay không
    if ext.lower() in [".jpg", ".jpeg", ".png"]:

        # Tải hình ảnh
        img = cv2.imread(os.path.join(input_dir, file))

        img = cv2.cvtColor( img, cv2.COLOR_BGR2HSV)

        # Lưu ảnh màu đỏ đã chuyển đổi
        cv2.imwrite(os.path.join(output_dir, file), img)

# %%
# Tạo thư mục mới để lưu trữ các ảnh màu đỏ
output_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset_after/test/Autorun.K'
os.makedirs(output_dir, exist_ok=True)

# Liệt kê tất cả các tệp hình ảnh trong thư mục gốc
input_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset/test/Autorun.K'
files = os.listdir(input_dir)

# Lặp qua từng tệp hình ảnh
for file in files:

    # Lấy tên tệp và phần mở rộng
    filename, ext = os.path.splitext(file)

    # Kiểm tra xem tệp có phải là ảnh trắng đen hay không
    if ext.lower() in [".jpg", ".jpeg", ".png"]:

        # Tải hình ảnh
        img = cv2.imread(os.path.join(input_dir, file))

        img = cv2.cvtColor( img, cv2.COLOR_BGR2HSV)

        # Lưu ảnh màu đỏ đã chuyển đổi
        cv2.imwrite(os.path.join(output_dir, file), img)

# %%
# Tạo thư mục mới để lưu trữ các ảnh màu đỏ
output_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset_after/test/C2LOP.P'
os.makedirs(output_dir, exist_ok=True)

# Liệt kê tất cả các tệp hình ảnh trong thư mục gốc
input_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset/test/C2LOP.P'
files = os.listdir(input_dir)

# Lặp qua từng tệp hình ảnh
for file in files:

    # Lấy tên tệp và phần mở rộng
    filename, ext = os.path.splitext(file)

    # Kiểm tra xem tệp có phải là ảnh trắng đen hay không
    if ext.lower() in [".jpg", ".jpeg", ".png"]:

        # Tải hình ảnh
        img = cv2.imread(os.path.join(input_dir, file))

        img = cv2.cvtColor( img, cv2.COLOR_BGR2HSV)

        # Lưu ảnh màu đỏ đã chuyển đổi
        cv2.imwrite(os.path.join(output_dir, file), img)

# %%
# Tạo thư mục mới để lưu trữ các ảnh màu đỏ
output_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset_after/test/C2LOP.gen!g'
os.makedirs(output_dir, exist_ok=True)

# Liệt kê tất cả các tệp hình ảnh trong thư mục gốc
input_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset/test/C2LOP.gen!g'
files = os.listdir(input_dir)

# Lặp qua từng tệp hình ảnh
for file in files:

    # Lấy tên tệp và phần mở rộng
    filename, ext = os.path.splitext(file)

    # Kiểm tra xem tệp có phải là ảnh trắng đen hay không
    if ext.lower() in [".jpg", ".jpeg", ".png"]:

        # Tải hình ảnh
        img = cv2.imread(os.path.join(input_dir, file))

        img = cv2.cvtColor( img, cv2.COLOR_BGR2HSV)

        # Lưu ảnh màu đỏ đã chuyển đổi
        cv2.imwrite(os.path.join(output_dir, file), img)

# %%
# Tạo thư mục mới để lưu trữ các ảnh màu đỏ
output_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset_after/test/Dialplatform.B'
os.makedirs(output_dir, exist_ok=True)

# Liệt kê tất cả các tệp hình ảnh trong thư mục gốc
input_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset/test/Dialplatform.B'
files = os.listdir(input_dir)

# Lặp qua từng tệp hình ảnh
for file in files:

    # Lấy tên tệp và phần mở rộng
    filename, ext = os.path.splitext(file)

    # Kiểm tra xem tệp có phải là ảnh trắng đen hay không
    if ext.lower() in [".jpg", ".jpeg", ".png"]:

        # Tải hình ảnh
        img = cv2.imread(os.path.join(input_dir, file))

        img = cv2.cvtColor( img, cv2.COLOR_BGR2HSV)

        # Lưu ảnh màu đỏ đã chuyển đổi
        cv2.imwrite(os.path.join(output_dir, file), img)

# %%
# Tạo thư mục mới để lưu trữ các ảnh màu đỏ
output_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset_after/test/Dontovo.A'
os.makedirs(output_dir, exist_ok=True)

# Liệt kê tất cả các tệp hình ảnh trong thư mục gốc
input_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset/test/Dontovo.A'
files = os.listdir(input_dir)

# Lặp qua từng tệp hình ảnh
for file in files:

    # Lấy tên tệp và phần mở rộng
    filename, ext = os.path.splitext(file)

    # Kiểm tra xem tệp có phải là ảnh trắng đen hay không
    if ext.lower() in [".jpg", ".jpeg", ".png"]:

        # Tải hình ảnh
        img = cv2.imread(os.path.join(input_dir, file))

        img = cv2.cvtColor( img, cv2.COLOR_BGR2HSV)

        # Lưu ảnh màu đỏ đã chuyển đổi
        cv2.imwrite(os.path.join(output_dir, file), img)

# %%
# Tạo thư mục mới để lưu trữ các ảnh màu đỏ
output_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset_after/test/Fakerean'
os.makedirs(output_dir, exist_ok=True)

# Liệt kê tất cả các tệp hình ảnh trong thư mục gốc
input_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset/test/Fakerean'
files = os.listdir(input_dir)

# Lặp qua từng tệp hình ảnh
for file in files:

    # Lấy tên tệp và phần mở rộng
    filename, ext = os.path.splitext(file)

    # Kiểm tra xem tệp có phải là ảnh trắng đen hay không
    if ext.lower() in [".jpg", ".jpeg", ".png"]:

        # Tải hình ảnh
        img = cv2.imread(os.path.join(input_dir, file))

        img = cv2.cvtColor( img, cv2.COLOR_BGR2HSV)

        # Lưu ảnh màu đỏ đã chuyển đổi
        cv2.imwrite(os.path.join(output_dir, file), img)

# %%
# Tạo thư mục mới để lưu trữ các ảnh màu đỏ
output_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset_after/test/Instantaccess'
os.makedirs(output_dir, exist_ok=True)

# Liệt kê tất cả các tệp hình ảnh trong thư mục gốc
input_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset/test/Instantaccess'
files = os.listdir(input_dir)

# Lặp qua từng tệp hình ảnh
for file in files:

    # Lấy tên tệp và phần mở rộng
    filename, ext = os.path.splitext(file)

    # Kiểm tra xem tệp có phải là ảnh trắng đen hay không
    if ext.lower() in [".jpg", ".jpeg", ".png"]:

        # Tải hình ảnh
        img = cv2.imread(os.path.join(input_dir, file))

        img = cv2.cvtColor( img, cv2.COLOR_BGR2HSV)

        # Lưu ảnh màu đỏ đã chuyển đổi
        cv2.imwrite(os.path.join(output_dir, file), img)

# %%
# Tạo thư mục mới để lưu trữ các ảnh màu đỏ
output_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset_after/test/Lolyda.AA1'
os.makedirs(output_dir, exist_ok=True)

# Liệt kê tất cả các tệp hình ảnh trong thư mục gốc
input_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset/test/Lolyda.AA1'
files = os.listdir(input_dir)

# Lặp qua từng tệp hình ảnh
for file in files:

    # Lấy tên tệp và phần mở rộng
    filename, ext = os.path.splitext(file)

    # Kiểm tra xem tệp có phải là ảnh trắng đen hay không
    if ext.lower() in [".jpg", ".jpeg", ".png"]:

        # Tải hình ảnh
        img = cv2.imread(os.path.join(input_dir, file))

        img = cv2.cvtColor( img, cv2.COLOR_BGR2HSV)

        # Lưu ảnh màu đỏ đã chuyển đổi
        cv2.imwrite(os.path.join(output_dir, file), img)

# %%
# Tạo thư mục mới để lưu trữ các ảnh màu đỏ
output_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset_after/test/Lolyda.AA2'
os.makedirs(output_dir, exist_ok=True)

# Liệt kê tất cả các tệp hình ảnh trong thư mục gốc
input_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset/test/Lolyda.AA2'
files = os.listdir(input_dir)

# Lặp qua từng tệp hình ảnh
for file in files:

    # Lấy tên tệp và phần mở rộng
    filename, ext = os.path.splitext(file)

    # Kiểm tra xem tệp có phải là ảnh trắng đen hay không
    if ext.lower() in [".jpg", ".jpeg", ".png"]:

        # Tải hình ảnh
        img = cv2.imread(os.path.join(input_dir, file))

        img = cv2.cvtColor( img, cv2.COLOR_BGR2HSV)

        # Lưu ảnh màu đỏ đã chuyển đổi
        cv2.imwrite(os.path.join(output_dir, file), img)

# %%
# Tạo thư mục mới để lưu trữ các ảnh màu đỏ
output_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset_after/test/Lolyda.AA3'
os.makedirs(output_dir, exist_ok=True)

# Liệt kê tất cả các tệp hình ảnh trong thư mục gốc
input_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset/test/Lolyda.AA3'
files = os.listdir(input_dir)

# Lặp qua từng tệp hình ảnh
for file in files:

    # Lấy tên tệp và phần mở rộng
    filename, ext = os.path.splitext(file)

    # Kiểm tra xem tệp có phải là ảnh trắng đen hay không
    if ext.lower() in [".jpg", ".jpeg", ".png"]:

        # Tải hình ảnh
        img = cv2.imread(os.path.join(input_dir, file))

        img = cv2.cvtColor( img, cv2.COLOR_BGR2HSV)

        # Lưu ảnh màu đỏ đã chuyển đổi
        cv2.imwrite(os.path.join(output_dir, file), img)

# %%
# Tạo thư mục mới để lưu trữ các ảnh màu đỏ
output_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset_after/test/Lolyda.AT'
os.makedirs(output_dir, exist_ok=True)

# Liệt kê tất cả các tệp hình ảnh trong thư mục gốc
input_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset/test/Lolyda.AT'
files = os.listdir(input_dir)

# Lặp qua từng tệp hình ảnh
for file in files:

    # Lấy tên tệp và phần mở rộng
    filename, ext = os.path.splitext(file)

    # Kiểm tra xem tệp có phải là ảnh trắng đen hay không
    if ext.lower() in [".jpg", ".jpeg", ".png"]:

        # Tải hình ảnh
        img = cv2.imread(os.path.join(input_dir, file))

        img = cv2.cvtColor( img, cv2.COLOR_BGR2HSV)

        # Lưu ảnh màu đỏ đã chuyển đổi
        cv2.imwrite(os.path.join(output_dir, file), img)

# %%
# Tạo thư mục mới để lưu trữ các ảnh màu đỏ
output_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset_after/test/Malex.gen!J'
os.makedirs(output_dir, exist_ok=True)

# Liệt kê tất cả các tệp hình ảnh trong thư mục gốc
input_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset/test/Malex.gen!J'
files = os.listdir(input_dir)

# Lặp qua từng tệp hình ảnh
for file in files:

    # Lấy tên tệp và phần mở rộng
    filename, ext = os.path.splitext(file)

    # Kiểm tra xem tệp có phải là ảnh trắng đen hay không
    if ext.lower() in [".jpg", ".jpeg", ".png"]:

        # Tải hình ảnh
        img = cv2.imread(os.path.join(input_dir, file))

        img = cv2.cvtColor( img, cv2.COLOR_BGR2HSV)

        # Lưu ảnh màu đỏ đã chuyển đổi
        cv2.imwrite(os.path.join(output_dir, file), img)

# %%
# Tạo thư mục mới để lưu trữ các ảnh màu đỏ
output_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset_after/test/Obfuscator.AD'
os.makedirs(output_dir, exist_ok=True)

# Liệt kê tất cả các tệp hình ảnh trong thư mục gốc
input_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset/test/Obfuscator.AD'
files = os.listdir(input_dir)

# Lặp qua từng tệp hình ảnh
for file in files:

    # Lấy tên tệp và phần mở rộng
    filename, ext = os.path.splitext(file)

    # Kiểm tra xem tệp có phải là ảnh trắng đen hay không
    if ext.lower() in [".jpg", ".jpeg", ".png"]:

        # Tải hình ảnh
        img = cv2.imread(os.path.join(input_dir, file))

        img = cv2.cvtColor( img, cv2.COLOR_BGR2HSV)

        # Lưu ảnh màu đỏ đã chuyển đổi
        cv2.imwrite(os.path.join(output_dir, file), img)

# %%
# Tạo thư mục mới để lưu trữ các ảnh màu đỏ
output_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset_after/test/Rbot!gen'
os.makedirs(output_dir, exist_ok=True)

# Liệt kê tất cả các tệp hình ảnh trong thư mục gốc
input_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset/test/Rbot!gen'
files = os.listdir(input_dir)

# Lặp qua từng tệp hình ảnh
for file in files:

    # Lấy tên tệp và phần mở rộng
    filename, ext = os.path.splitext(file)

    # Kiểm tra xem tệp có phải là ảnh trắng đen hay không
    if ext.lower() in [".jpg", ".jpeg", ".png"]:

        # Tải hình ảnh
        img = cv2.imread(os.path.join(input_dir, file))

        img = cv2.cvtColor( img, cv2.COLOR_BGR2HSV)

        # Lưu ảnh màu đỏ đã chuyển đổi
        cv2.imwrite(os.path.join(output_dir, file), img)

# %%
# Tạo thư mục mới để lưu trữ các ảnh màu đỏ
output_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset_after/test/Skintrim.N'
os.makedirs(output_dir, exist_ok=True)

# Liệt kê tất cả các tệp hình ảnh trong thư mục gốc
input_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset/test/Skintrim.N'
files = os.listdir(input_dir)

# Lặp qua từng tệp hình ảnh
for file in files:

    # Lấy tên tệp và phần mở rộng
    filename, ext = os.path.splitext(file)

    # Kiểm tra xem tệp có phải là ảnh trắng đen hay không
    if ext.lower() in [".jpg", ".jpeg", ".png"]:

        # Tải hình ảnh
        img = cv2.imread(os.path.join(input_dir, file))

        img = cv2.cvtColor( img, cv2.COLOR_BGR2HSV)

        # Lưu ảnh màu đỏ đã chuyển đổi
        cv2.imwrite(os.path.join(output_dir, file), img)

# %%
# Tạo thư mục mới để lưu trữ các ảnh màu đỏ
output_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset_after/test/Swizzor.gen!E'
os.makedirs(output_dir, exist_ok=True)

# Liệt kê tất cả các tệp hình ảnh trong thư mục gốc
input_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset/test/Swizzor.gen!E'
files = os.listdir(input_dir)

# Lặp qua từng tệp hình ảnh
for file in files:

    # Lấy tên tệp và phần mở rộng
    filename, ext = os.path.splitext(file)

    # Kiểm tra xem tệp có phải là ảnh trắng đen hay không
    if ext.lower() in [".jpg", ".jpeg", ".png"]:

        # Tải hình ảnh
        img = cv2.imread(os.path.join(input_dir, file))

        img = cv2.cvtColor( img, cv2.COLOR_BGR2HSV)

        # Lưu ảnh màu đỏ đã chuyển đổi
        cv2.imwrite(os.path.join(output_dir, file), img)

# %%
# Tạo thư mục mới để lưu trữ các ảnh màu đỏ
output_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset_after/test/Swizzor.gen!I'
os.makedirs(output_dir, exist_ok=True)

# Liệt kê tất cả các tệp hình ảnh trong thư mục gốc
input_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset/test/Swizzor.gen!I'
files = os.listdir(input_dir)

# Lặp qua từng tệp hình ảnh
for file in files:

    # Lấy tên tệp và phần mở rộng
    filename, ext = os.path.splitext(file)

    # Kiểm tra xem tệp có phải là ảnh trắng đen hay không
    if ext.lower() in [".jpg", ".jpeg", ".png"]:

        # Tải hình ảnh
        img = cv2.imread(os.path.join(input_dir, file))

        img = cv2.cvtColor( img, cv2.COLOR_BGR2HSV)

        # Lưu ảnh màu đỏ đã chuyển đổi
        cv2.imwrite(os.path.join(output_dir, file), img)

# %%
# Tạo thư mục mới để lưu trữ các ảnh màu đỏ
output_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset_after/test/VB.AT'
os.makedirs(output_dir, exist_ok=True)

# Liệt kê tất cả các tệp hình ảnh trong thư mục gốc
input_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset/test/VB.AT'
files = os.listdir(input_dir)

# Lặp qua từng tệp hình ảnh
for file in files:

    # Lấy tên tệp và phần mở rộng
    filename, ext = os.path.splitext(file)

    # Kiểm tra xem tệp có phải là ảnh trắng đen hay không
    if ext.lower() in [".jpg", ".jpeg", ".png"]:

        # Tải hình ảnh
        img = cv2.imread(os.path.join(input_dir, file))

        img = cv2.cvtColor( img, cv2.COLOR_BGR2HSV)

        # Lưu ảnh màu đỏ đã chuyển đổi
        cv2.imwrite(os.path.join(output_dir, file), img)

# %%
# Tạo thư mục mới để lưu trữ các ảnh màu đỏ
output_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset_after/test/Wintrim.BX'
os.makedirs(output_dir, exist_ok=True)

# Liệt kê tất cả các tệp hình ảnh trong thư mục gốc
input_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset/test/Wintrim.BX'
files = os.listdir(input_dir)

# Lặp qua từng tệp hình ảnh
for file in files:

    # Lấy tên tệp và phần mở rộng
    filename, ext = os.path.splitext(file)

    # Kiểm tra xem tệp có phải là ảnh trắng đen hay không
    if ext.lower() in [".jpg", ".jpeg", ".png"]:

        # Tải hình ảnh
        img = cv2.imread(os.path.join(input_dir, file))

        img = cv2.cvtColor( img, cv2.COLOR_BGR2HSV)

        # Lưu ảnh màu đỏ đã chuyển đổi
        cv2.imwrite(os.path.join(output_dir, file), img)

# %%
# Tạo thư mục mới để lưu trữ các ảnh màu đỏ
output_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset_after/test/Yuner.A'
os.makedirs(output_dir, exist_ok=True)

# Liệt kê tất cả các tệp hình ảnh trong thư mục gốc
input_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset/test/Yuner.A'
files = os.listdir(input_dir)

# Lặp qua từng tệp hình ảnh
for file in files:

    # Lấy tên tệp và phần mở rộng
    filename, ext = os.path.splitext(file)

    # Kiểm tra xem tệp có phải là ảnh trắng đen hay không
    if ext.lower() in [".jpg", ".jpeg", ".png"]:

        # Tải hình ảnh
        img = cv2.imread(os.path.join(input_dir, file))

        img = cv2.cvtColor( img, cv2.COLOR_BGR2HSV)

        # Lưu ảnh màu đỏ đã chuyển đổi
        cv2.imwrite(os.path.join(output_dir, file), img)

# %%
import cv2
import os

# Tạo thư mục mới để lưu trữ các ảnh màu đỏ
output_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset_after/val/Allaple.A'
os.makedirs(output_dir, exist_ok=True)

# Liệt kê tất cả các tệp hình ảnh trong thư mục gốc
input_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset/val/Allaple.A'
files = os.listdir(input_dir)

# Lặp qua từng tệp hình ảnh
for file in files:

    # Lấy tên tệp và phần mở rộng
    filename, ext = os.path.splitext(file)

    # Kiểm tra xem tệp có phải là ảnh trắng đen hay không
    if ext.lower() in [".jpg", ".jpeg", ".png"]:

        # Tải hình ảnh
        img = cv2.imread(os.path.join(input_dir, file))

        img = cv2.cvtColor( img, cv2.COLOR_BGR2HSV)

        # Lưu ảnh màu đỏ đã chuyển đổi
        cv2.imwrite(os.path.join(output_dir, file), img)

# %%
# Tạo thư mục mới để lưu trữ các ảnh màu đỏ
output_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset_after/val/Adialer.C'
os.makedirs(output_dir, exist_ok=True)

# Liệt kê tất cả các tệp hình ảnh trong thư mục gốc
input_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset/val/Adialer.C'
files = os.listdir(input_dir)

# Lặp qua từng tệp hình ảnh
for file in files:

    # Lấy tên tệp và phần mở rộng
    filename, ext = os.path.splitext(file)

    # Kiểm tra xem tệp có phải là ảnh trắng đen hay không
    if ext.lower() in [".jpg", ".jpeg", ".png"]:

        # Tải hình ảnh
        img = cv2.imread(os.path.join(input_dir, file))

        img = cv2.cvtColor( img, cv2.COLOR_BGR2HSV)

        # Lưu ảnh màu đỏ đã chuyển đổi
        cv2.imwrite(os.path.join(output_dir, file), img)

# %%
# Tạo thư mục mới để lưu trữ các ảnh màu đỏ
output_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset_after/val/Agent.FYI'
os.makedirs(output_dir, exist_ok=True)

# Liệt kê tất cả các tệp hình ảnh trong thư mục gốc
input_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset/val/Agent.FYI'
files = os.listdir(input_dir)

# Lặp qua từng tệp hình ảnh
for file in files:

    # Lấy tên tệp và phần mở rộng
    filename, ext = os.path.splitext(file)

    # Kiểm tra xem tệp có phải là ảnh trắng đen hay không
    if ext.lower() in [".jpg", ".jpeg", ".png"]:

        # Tải hình ảnh
        img = cv2.imread(os.path.join(input_dir, file))

        img = cv2.cvtColor( img, cv2.COLOR_BGR2HSV)

        # Lưu ảnh màu đỏ đã chuyển đổi
        cv2.imwrite(os.path.join(output_dir, file), img)

# %%
# Tạo thư mục mới để lưu trữ các ảnh màu đỏ
output_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset_after/val/Allaple.L'
os.makedirs(output_dir, exist_ok=True)

# Liệt kê tất cả các tệp hình ảnh trong thư mục gốc
input_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset/val/Allaple.L'
files = os.listdir(input_dir)

# Lặp qua từng tệp hình ảnh
for file in files:

    # Lấy tên tệp và phần mở rộng
    filename, ext = os.path.splitext(file)

    # Kiểm tra xem tệp có phải là ảnh trắng đen hay không
    if ext.lower() in [".jpg", ".jpeg", ".png"]:

        # Tải hình ảnh
        img = cv2.imread(os.path.join(input_dir, file))

        img = cv2.cvtColor( img, cv2.COLOR_BGR2HSV)

        # Lưu ảnh màu đỏ đã chuyển đổi
        cv2.imwrite(os.path.join(output_dir, file), img)

# %%
# Tạo thư mục mới để lưu trữ các ảnh màu đỏ
output_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset_after/val/Alueron.gen!J'
os.makedirs(output_dir, exist_ok=True)

# Liệt kê tất cả các tệp hình ảnh trong thư mục gốc
input_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset/val/Alueron.gen!J'
files = os.listdir(input_dir)

# Lặp qua từng tệp hình ảnh
for file in files:

    # Lấy tên tệp và phần mở rộng
    filename, ext = os.path.splitext(file)

    # Kiểm tra xem tệp có phải là ảnh trắng đen hay không
    if ext.lower() in [".jpg", ".jpeg", ".png"]:

        # Tải hình ảnh
        img = cv2.imread(os.path.join(input_dir, file))

        img = cv2.cvtColor( img, cv2.COLOR_BGR2HSV)

        # Lưu ảnh màu đỏ đã chuyển đổi
        cv2.imwrite(os.path.join(output_dir, file), img)

# %%
# Tạo thư mục mới để lưu trữ các ảnh màu đỏ
output_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset_after/val/Autorun.K'
os.makedirs(output_dir, exist_ok=True)

# Liệt kê tất cả các tệp hình ảnh trong thư mục gốc
input_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset/val/Autorun.K'
files = os.listdir(input_dir)

# Lặp qua từng tệp hình ảnh
for file in files:

    # Lấy tên tệp và phần mở rộng
    filename, ext = os.path.splitext(file)

    # Kiểm tra xem tệp có phải là ảnh trắng đen hay không
    if ext.lower() in [".jpg", ".jpeg", ".png"]:

        # Tải hình ảnh
        img = cv2.imread(os.path.join(input_dir, file))

        img = cv2.cvtColor( img, cv2.COLOR_BGR2HSV)

        # Lưu ảnh màu đỏ đã chuyển đổi
        cv2.imwrite(os.path.join(output_dir, file), img)

# %%
# Tạo thư mục mới để lưu trữ các ảnh màu đỏ
output_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset_after/val/C2LOP.P'
os.makedirs(output_dir, exist_ok=True)

# Liệt kê tất cả các tệp hình ảnh trong thư mục gốc
input_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset/val/C2LOP.P'
files = os.listdir(input_dir)

# Lặp qua từng tệp hình ảnh
for file in files:

    # Lấy tên tệp và phần mở rộng
    filename, ext = os.path.splitext(file)

    # Kiểm tra xem tệp có phải là ảnh trắng đen hay không
    if ext.lower() in [".jpg", ".jpeg", ".png"]:

        # Tải hình ảnh
        img = cv2.imread(os.path.join(input_dir, file))

        img = cv2.cvtColor( img, cv2.COLOR_BGR2HSV)

        # Lưu ảnh màu đỏ đã chuyển đổi
        cv2.imwrite(os.path.join(output_dir, file), img)

# %%
# Tạo thư mục mới để lưu trữ các ảnh màu đỏ
output_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset_after/val/C2LOP.gen!g'
os.makedirs(output_dir, exist_ok=True)

# Liệt kê tất cả các tệp hình ảnh trong thư mục gốc
input_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset/val/C2LOP.gen!g'
files = os.listdir(input_dir)

# Lặp qua từng tệp hình ảnh
for file in files:

    # Lấy tên tệp và phần mở rộng
    filename, ext = os.path.splitext(file)

    # Kiểm tra xem tệp có phải là ảnh trắng đen hay không
    if ext.lower() in [".jpg", ".jpeg", ".png"]:

        # Tải hình ảnh
        img = cv2.imread(os.path.join(input_dir, file))

        img = cv2.cvtColor( img, cv2.COLOR_BGR2HSV)

        # Lưu ảnh màu đỏ đã chuyển đổi
        cv2.imwrite(os.path.join(output_dir, file), img)

# %%
# Tạo thư mục mới để lưu trữ các ảnh màu đỏ
output_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset_after/val/Dialplatform.B'
os.makedirs(output_dir, exist_ok=True)

# Liệt kê tất cả các tệp hình ảnh trong thư mục gốc
input_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset/val/Dialplatform.B'
files = os.listdir(input_dir)

# Lặp qua từng tệp hình ảnh
for file in files:

    # Lấy tên tệp và phần mở rộng
    filename, ext = os.path.splitext(file)

    # Kiểm tra xem tệp có phải là ảnh trắng đen hay không
    if ext.lower() in [".jpg", ".jpeg", ".png"]:

        # Tải hình ảnh
        img = cv2.imread(os.path.join(input_dir, file))

        img = cv2.cvtColor( img, cv2.COLOR_BGR2HSV)

        # Lưu ảnh màu đỏ đã chuyển đổi
        cv2.imwrite(os.path.join(output_dir, file), img)

# %%
# Tạo thư mục mới để lưu trữ các ảnh màu đỏ
output_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset_after/val/Dontovo.A'
os.makedirs(output_dir, exist_ok=True)

# Liệt kê tất cả các tệp hình ảnh trong thư mục gốc
input_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset/val/Dontovo.A'
files = os.listdir(input_dir)

# Lặp qua từng tệp hình ảnh
for file in files:

    # Lấy tên tệp và phần mở rộng
    filename, ext = os.path.splitext(file)

    # Kiểm tra xem tệp có phải là ảnh trắng đen hay không
    if ext.lower() in [".jpg", ".jpeg", ".png"]:

        # Tải hình ảnh
        img = cv2.imread(os.path.join(input_dir, file))

        img = cv2.cvtColor( img, cv2.COLOR_BGR2HSV)

        # Lưu ảnh màu đỏ đã chuyển đổi
        cv2.imwrite(os.path.join(output_dir, file), img)

# %%
# Tạo thư mục mới để lưu trữ các ảnh màu đỏ
output_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset_after/val/Fakerean'
os.makedirs(output_dir, exist_ok=True)

# Liệt kê tất cả các tệp hình ảnh trong thư mục gốc
input_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset/val/Fakerean'
files = os.listdir(input_dir)

# Lặp qua từng tệp hình ảnh
for file in files:

    # Lấy tên tệp và phần mở rộng
    filename, ext = os.path.splitext(file)

    # Kiểm tra xem tệp có phải là ảnh trắng đen hay không
    if ext.lower() in [".jpg", ".jpeg", ".png"]:

        # Tải hình ảnh
        img = cv2.imread(os.path.join(input_dir, file))

        img = cv2.cvtColor( img, cv2.COLOR_BGR2HSV)

        # Lưu ảnh màu đỏ đã chuyển đổi
        cv2.imwrite(os.path.join(output_dir, file), img)

# %%
# Tạo thư mục mới để lưu trữ các ảnh màu đỏ
output_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset_after/val/Instantaccess'
os.makedirs(output_dir, exist_ok=True)

# Liệt kê tất cả các tệp hình ảnh trong thư mục gốc
input_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset/val/Instantaccess'
files = os.listdir(input_dir)

# Lặp qua từng tệp hình ảnh
for file in files:

    # Lấy tên tệp và phần mở rộng
    filename, ext = os.path.splitext(file)

    # Kiểm tra xem tệp có phải là ảnh trắng đen hay không
    if ext.lower() in [".jpg", ".jpeg", ".png"]:

        # Tải hình ảnh
        img = cv2.imread(os.path.join(input_dir, file))

        img = cv2.cvtColor( img, cv2.COLOR_BGR2HSV)

        # Lưu ảnh màu đỏ đã chuyển đổi
        cv2.imwrite(os.path.join(output_dir, file), img)

# %%
# Tạo thư mục mới để lưu trữ các ảnh màu đỏ
output_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset_after/val/Lolyda.AA1'
os.makedirs(output_dir, exist_ok=True)

# Liệt kê tất cả các tệp hình ảnh trong thư mục gốc
input_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset/val/Lolyda.AA1'
files = os.listdir(input_dir)

# Lặp qua từng tệp hình ảnh
for file in files:

    # Lấy tên tệp và phần mở rộng
    filename, ext = os.path.splitext(file)

    # Kiểm tra xem tệp có phải là ảnh trắng đen hay không
    if ext.lower() in [".jpg", ".jpeg", ".png"]:

        # Tải hình ảnh
        img = cv2.imread(os.path.join(input_dir, file))

        img = cv2.cvtColor( img, cv2.COLOR_BGR2HSV)

        # Lưu ảnh màu đỏ đã chuyển đổi
        cv2.imwrite(os.path.join(output_dir, file), img)

# %%
# Tạo thư mục mới để lưu trữ các ảnh màu đỏ
output_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset_after/val/Lolyda.AA2'
os.makedirs(output_dir, exist_ok=True)

# Liệt kê tất cả các tệp hình ảnh trong thư mục gốc
input_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset/val/Lolyda.AA2'
files = os.listdir(input_dir)

# Lặp qua từng tệp hình ảnh
for file in files:

    # Lấy tên tệp và phần mở rộng
    filename, ext = os.path.splitext(file)

    # Kiểm tra xem tệp có phải là ảnh trắng đen hay không
    if ext.lower() in [".jpg", ".jpeg", ".png"]:

        # Tải hình ảnh
        img = cv2.imread(os.path.join(input_dir, file))

        img = cv2.cvtColor( img, cv2.COLOR_BGR2HSV)

        # Lưu ảnh màu đỏ đã chuyển đổi
        cv2.imwrite(os.path.join(output_dir, file), img)

# %%
# Tạo thư mục mới để lưu trữ các ảnh màu đỏ
output_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset_after/val/Lolyda.AA3'
os.makedirs(output_dir, exist_ok=True)

# Liệt kê tất cả các tệp hình ảnh trong thư mục gốc
input_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset/val/Lolyda.AA3'
files = os.listdir(input_dir)

# Lặp qua từng tệp hình ảnh
for file in files:

    # Lấy tên tệp và phần mở rộng
    filename, ext = os.path.splitext(file)

    # Kiểm tra xem tệp có phải là ảnh trắng đen hay không
    if ext.lower() in [".jpg", ".jpeg", ".png"]:

        # Tải hình ảnh
        img = cv2.imread(os.path.join(input_dir, file))

        img = cv2.cvtColor( img, cv2.COLOR_BGR2HSV)

        # Lưu ảnh màu đỏ đã chuyển đổi
        cv2.imwrite(os.path.join(output_dir, file), img)

# %%
# Tạo thư mục mới để lưu trữ các ảnh màu đỏ
output_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset_after/val/Lolyda.AT'
os.makedirs(output_dir, exist_ok=True)

# Liệt kê tất cả các tệp hình ảnh trong thư mục gốc
input_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset/val/Lolyda.AT'
files = os.listdir(input_dir)

# Lặp qua từng tệp hình ảnh
for file in files:

    # Lấy tên tệp và phần mở rộng
    filename, ext = os.path.splitext(file)

    # Kiểm tra xem tệp có phải là ảnh trắng đen hay không
    if ext.lower() in [".jpg", ".jpeg", ".png"]:

        # Tải hình ảnh
        img = cv2.imread(os.path.join(input_dir, file))

        img = cv2.cvtColor( img, cv2.COLOR_BGR2HSV)

        # Lưu ảnh màu đỏ đã chuyển đổi
        cv2.imwrite(os.path.join(output_dir, file), img)

# %%
# Tạo thư mục mới để lưu trữ các ảnh màu đỏ
output_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset_after/val/Malex.gen!J'
os.makedirs(output_dir, exist_ok=True)

# Liệt kê tất cả các tệp hình ảnh trong thư mục gốc
input_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset/val/Malex.gen!J'
files = os.listdir(input_dir)

# Lặp qua từng tệp hình ảnh
for file in files:

    # Lấy tên tệp và phần mở rộng
    filename, ext = os.path.splitext(file)

    # Kiểm tra xem tệp có phải là ảnh trắng đen hay không
    if ext.lower() in [".jpg", ".jpeg", ".png"]:

        # Tải hình ảnh
        img = cv2.imread(os.path.join(input_dir, file))

        img = cv2.cvtColor( img, cv2.COLOR_BGR2HSV)

        # Lưu ảnh màu đỏ đã chuyển đổi
        cv2.imwrite(os.path.join(output_dir, file), img)

# %%
# Tạo thư mục mới để lưu trữ các ảnh màu đỏ
output_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset_after/val/Obfuscator.AD'
os.makedirs(output_dir, exist_ok=True)

# Liệt kê tất cả các tệp hình ảnh trong thư mục gốc
input_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset/val/Obfuscator.AD'
files = os.listdir(input_dir)

# Lặp qua từng tệp hình ảnh
for file in files:

    # Lấy tên tệp và phần mở rộng
    filename, ext = os.path.splitext(file)

    # Kiểm tra xem tệp có phải là ảnh trắng đen hay không
    if ext.lower() in [".jpg", ".jpeg", ".png"]:

        # Tải hình ảnh
        img = cv2.imread(os.path.join(input_dir, file))

        img = cv2.cvtColor( img, cv2.COLOR_BGR2HSV)

        # Lưu ảnh màu đỏ đã chuyển đổi
        cv2.imwrite(os.path.join(output_dir, file), img)

# %%
# Tạo thư mục mới để lưu trữ các ảnh màu đỏ
output_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset_after/val/Rbot!gen'
os.makedirs(output_dir, exist_ok=True)

# Liệt kê tất cả các tệp hình ảnh trong thư mục gốc
input_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset/val/Rbot!gen'
files = os.listdir(input_dir)

# Lặp qua từng tệp hình ảnh
for file in files:

    # Lấy tên tệp và phần mở rộng
    filename, ext = os.path.splitext(file)

    # Kiểm tra xem tệp có phải là ảnh trắng đen hay không
    if ext.lower() in [".jpg", ".jpeg", ".png"]:

        # Tải hình ảnh
        img = cv2.imread(os.path.join(input_dir, file))

        img = cv2.cvtColor( img, cv2.COLOR_BGR2HSV)

        # Lưu ảnh màu đỏ đã chuyển đổi
        cv2.imwrite(os.path.join(output_dir, file), img)

# %%
# Tạo thư mục mới để lưu trữ các ảnh màu đỏ
output_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset_after/val/Skintrim.N'
os.makedirs(output_dir, exist_ok=True)

# Liệt kê tất cả các tệp hình ảnh trong thư mục gốc
input_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset/val/Skintrim.N'
files = os.listdir(input_dir)

# Lặp qua từng tệp hình ảnh
for file in files:

    # Lấy tên tệp và phần mở rộng
    filename, ext = os.path.splitext(file)

    # Kiểm tra xem tệp có phải là ảnh trắng đen hay không
    if ext.lower() in [".jpg", ".jpeg", ".png"]:

        # Tải hình ảnh
        img = cv2.imread(os.path.join(input_dir, file))

        img = cv2.cvtColor( img, cv2.COLOR_BGR2HSV)

        # Lưu ảnh màu đỏ đã chuyển đổi
        cv2.imwrite(os.path.join(output_dir, file), img)

# %%
# Tạo thư mục mới để lưu trữ các ảnh màu đỏ
output_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset_after/val/Swizzor.gen!E'
os.makedirs(output_dir, exist_ok=True)

# Liệt kê tất cả các tệp hình ảnh trong thư mục gốc
input_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset/val/Swizzor.gen!E'
files = os.listdir(input_dir)

# Lặp qua từng tệp hình ảnh
for file in files:

    # Lấy tên tệp và phần mở rộng
    filename, ext = os.path.splitext(file)

    # Kiểm tra xem tệp có phải là ảnh trắng đen hay không
    if ext.lower() in [".jpg", ".jpeg", ".png"]:

        # Tải hình ảnh
        img = cv2.imread(os.path.join(input_dir, file))

        img = cv2.cvtColor( img, cv2.COLOR_BGR2HSV)

        # Lưu ảnh màu đỏ đã chuyển đổi
        cv2.imwrite(os.path.join(output_dir, file), img)

# %%
# Tạo thư mục mới để lưu trữ các ảnh màu đỏ
output_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset_after/val/Swizzor.gen!I'
os.makedirs(output_dir, exist_ok=True)

# Liệt kê tất cả các tệp hình ảnh trong thư mục gốc
input_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset/val/Swizzor.gen!I'
files = os.listdir(input_dir)

# Lặp qua từng tệp hình ảnh
for file in files:

    # Lấy tên tệp và phần mở rộng
    filename, ext = os.path.splitext(file)

    # Kiểm tra xem tệp có phải là ảnh trắng đen hay không
    if ext.lower() in [".jpg", ".jpeg", ".png"]:

        # Tải hình ảnh
        img = cv2.imread(os.path.join(input_dir, file))

        img = cv2.cvtColor( img, cv2.COLOR_BGR2HSV)

        # Lưu ảnh màu đỏ đã chuyển đổi
        cv2.imwrite(os.path.join(output_dir, file), img)

# %%
# Tạo thư mục mới để lưu trữ các ảnh màu đỏ
output_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset_after/val/VB.AT'
os.makedirs(output_dir, exist_ok=True)

# Liệt kê tất cả các tệp hình ảnh trong thư mục gốc
input_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset/val/VB.AT'
files = os.listdir(input_dir)

# Lặp qua từng tệp hình ảnh
for file in files:

    # Lấy tên tệp và phần mở rộng
    filename, ext = os.path.splitext(file)

    # Kiểm tra xem tệp có phải là ảnh trắng đen hay không
    if ext.lower() in [".jpg", ".jpeg", ".png"]:

        # Tải hình ảnh
        img = cv2.imread(os.path.join(input_dir, file))

        img = cv2.cvtColor( img, cv2.COLOR_BGR2HSV)

        # Lưu ảnh màu đỏ đã chuyển đổi
        cv2.imwrite(os.path.join(output_dir, file), img)

# %%
# Tạo thư mục mới để lưu trữ các ảnh màu đỏ
output_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset_after/val/Wintrim.BX'
os.makedirs(output_dir, exist_ok=True)

# Liệt kê tất cả các tệp hình ảnh trong thư mục gốc
input_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset/val/Wintrim.BX'
files = os.listdir(input_dir)

# Lặp qua từng tệp hình ảnh
for file in files:

    # Lấy tên tệp và phần mở rộng
    filename, ext = os.path.splitext(file)

    # Kiểm tra xem tệp có phải là ảnh trắng đen hay không
    if ext.lower() in [".jpg", ".jpeg", ".png"]:

        # Tải hình ảnh
        img = cv2.imread(os.path.join(input_dir, file))

        img = cv2.cvtColor( img, cv2.COLOR_BGR2HSV)

        # Lưu ảnh màu đỏ đã chuyển đổi
        cv2.imwrite(os.path.join(output_dir, file), img)

# %%
# Tạo thư mục mới để lưu trữ các ảnh màu đỏ
output_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset_after/val/Yuner.A'
os.makedirs(output_dir, exist_ok=True)

# Liệt kê tất cả các tệp hình ảnh trong thư mục gốc
input_dir = '/content/drive/MyDrive/IE105/model/malimg_dataset/val/Yuner.A'
files = os.listdir(input_dir)

# Lặp qua từng tệp hình ảnh
for file in files:

    # Lấy tên tệp và phần mở rộng
    filename, ext = os.path.splitext(file)

    # Kiểm tra xem tệp có phải là ảnh trắng đen hay không
    if ext.lower() in [".jpg", ".jpeg", ".png"]:

        # Tải hình ảnh
        img = cv2.imread(os.path.join(input_dir, file))

        img = cv2.cvtColor( img, cv2.COLOR_BGR2HSV)

        # Lưu ảnh màu đỏ đã chuyển đổi
        cv2.imwrite(os.path.join(output_dir, file), img)
